# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# تفریحی
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     در این تمرین قصد داریم به پیشبینی دلیل سفر کاربران بپردازیم. برخی از کاربران مستربلیط به دلیل کاری و برخی دیگر به دلایل تفریحی به سفر می‌روند. به منظور شخصی‌سازی بیشتر و دقیق‌تر، مستربلیط قصد دارد بداند هر بلیط به چه دلیلی رزرو می‌شود.
#     <br>
#     حال از داده‌هایی که در اختیارتان قرار گرفته است استفاده کنید و مدلی آموزش دهید که تفریحی یا کاری بودن سفر را تشخیص دهد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
# مجموعه داده آموزشی شامل ۱۰۱۰۱۷ سطر است که در جدول زیر، توضیحات هر ستون آمده است.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |Created|زمان ثبت بلیط|
# |CancelTime|زمانی که مسافر بلیط را کنسل کرده است|
# |DepartureTime|زمان حرکت|
# |BillID|شناسه خرید|
# |TicketID|شناسه بلیط|
# |ReserveStatus|وضعیت پرداخت مشتری|
# |UserID|شناسه کاربری|
# |Male|آیا بلیط متعلق به زن است یا مرد|
# |Price|قیمت بلیط بدون تخفیف|
# |CouponDiscount|تخفیفی که شخص روی بلیط اعمال کرده است|
# |From|مبدا سفر|
# |To|مقصد سفر|
# |Domestic|آیا سفر، داخلی است یا خارجی|
# |VehicleType|جزئیات وسیله نقلیه را مشخص می‌کند|
# |VehicleClass|آیا وسیله نقلیه، فرست‌کلس است یا نه|
# |Vehicle|نوع وسیله نقلیه|
# |Cancel|آیا بلیط کنسل شده‌است یا نه|
# |HashPassportNumber_p|هش‌شده شماره پاسپورت|
# |HashEmail|هش‌شده ایمیل|
# |BuyerMobile|هش‌شده شماره موبایل|
# |NationalCode|هش‌شده شماره‌ملی|
# |TripReason|دلیل سفر|
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     مجموعه داده آزمایش نیز مانند مجموعه آموزش است با این تفاوت که ستون <code>TripReason</code> که متغیر هدف مسئله است را در خود ندارد. مجموعه داده آزمایش ۴۳۲۹۳ سطر دارد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     در ابتدا نیاز است فایل‌های مجموعه‌داده را بخوانید. نمونه‌های آموزشی در فایل <code>train.csv</code> و نمونه‌های آزمون که باید دسته‌ی آن‌ها را پیش‌بینی کنید در فایل <code>test.csv</code> ذخیره شده‌اند. اگر لازم دانستید می‌توانید به دلخواه خود بخشی از دادگان آموزشی را به عنوان دادگان اعتبارسنجی نیز جدا کنید.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/train_data.csv')
train_data.isna().sum()
# Out:
# Created                      0
# CancelTime               85691
# DepartureTime                0
# BillID                       0
# TicketID                     0
# ReserveStatus                0
# UserID                   58474
# Male                         0
# Price                        0
# CouponDiscount               0
# From                         0
# To                           0
# Domestic                     0
# VehicleType               7544
# VehicleClass             38450
# TripReason                   0
# Vehicle                      0
# Cancel                       0
# HashPassportNumber_p    100155
# HashEmail                57933
# BuyerMobile                  0
# NationalCode                 0
# dtype: int64

# %%
test_data = pd.read_csv('../data/test_data.csv')
test_data
# Out:
#                        Created               CancelTime        DepartureTime  \
# 0      2022-07-22 12:52:35.293                      NaN  2022-08-03 17:00:00
# 1      2022-05-16 10:55:29.397  2022-05-18 11:35:15.643  2022-05-19 17:00:00
# 2      2022-02-13 16:10:33.870                      NaN  2022-02-15 22:45:00
# 3      2022-05-01 17:56:18.530                      NaN  2022-05-06 14:30:00
# 4      2022-05-19 18:40:48.760                      NaN  2022-05-21 12:30:00
# ...                        ...                      ...                  ...
# 43288  2022-10-06 16:57:16.053                      NaN  2022-10-07 21:00:00
# 43289  2022-06-14 13:19:26.413                      NaN  2022-06-18 07:15:00
# 43290  2022-10-23 15:48:03.947                      NaN  2022-10-23 20:25:00
# 43291  2022-09-18 21:18:01.730  2022-09-19 15:40:44.707  2022-09-20 20:00:00
# 43292  2022-07-27 22:08:17.510  2022-07-30 19:19:29.357  2022-08-03 21:00:00
#
# ...

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     در این سوال شما می‌توانید از هر تکنیک پیش‌پردازش/مهندسی ویژگی که در فصل‌های گذشته آموختید، استفاده کنید.
#     <br>
#     تکنیک‌هایی که استفاده می‌کنید به شکل مستقیم مورد ارزیابی توسط سامانه داوری قرار <b>نمی‌گیرند.</b> بلکه همه آن‌ها در دقت مدل شما تاثیر خواهند گذاشت؛ بنابراین هر چه پیش‌پردازش/مهندسی ویژگی بهتری انجام دهید تا دقت مدل بهبود پیدا کند، امتیاز بیشتری از این سوال کسب خواهید کرد.
# </font>
# </p>

# %%
# do some preprocessing

# %%
train_data.drop(columns = ['CancelTime','UserID','HashPassportNumber_p','HashEmail','BuyerMobile','NationalCode'],inplace = True)

# %%
# Filling missing value
mod = train_data.groupby('Vehicle')['VehicleType'].transform(lambda x : x.mode()[0])
train_data['VehicleType'] = train_data.groupby('Vehicle')['VehicleType'].fillna(mod)
mod = train_data.groupby('VehicleType')['VehicleClass'].transform(lambda x: x.mode()[0] if not x.mode().empty else 0)
train_data['VehicleClass'] = train_data.groupby('VehicleType')['VehicleClass'].fillna(mod)
mod = test_data.groupby('Vehicle')['VehicleType'].transform(lambda x : x.mode()[0])
test_data['VehicleType'] = test_data.groupby('Vehicle')['VehicleType'].fillna(mod)
mod = test_data.groupby('VehicleType')['VehicleClass'].transform(lambda x: x.mode()[0] if not x.mode().empty else 0)
test_data['VehicleClass'] = test_data.groupby('VehicleType')['VehicleClass'].fillna(mod)

# train_data['VehicleClass'].fillna(train_data['VehicleClass'].mode()[0], inplace=True)
# test_data['VehicleClass'].fillna(test_data['VehicleClass'].mode()[0], inplace=True)
# train_data['VehicleType'].fillna(train_data['VehicleType'].mode()[0], inplace=True)
# test_data['VehicleType'].fillna(test_data['VehicleType'].mode()[0], inplace=True)

# %%
train_data['Family'] = train_data.groupby('BillID')['TicketID'].transform('count')
test_data['Family'] = test_data.groupby('BillID')['TicketID'].transform('count')

# %%
def func(month) :
    if month == 0 or month == 1 or month == 2 :
        return 1
    elif month == 3 or month == 4 or month == 5 :
        return 2
    elif month == 6 or month == 7 or month == 8  :
        return 3
    else :
        return 4
train_data['blit_gap'] = (pd.to_datetime(train_data['DepartureTime'])- pd.to_datetime(train_data['Created'])).dt.days  
test_data['blit_gap'] = (pd.to_datetime(test_data['DepartureTime'])- pd.to_datetime(test_data['Created'])).dt.days
train_data['month'] = train_data['DepartureTime'].apply(lambda x: pd.to_datetime(x).month)
test_data['month'] = test_data['DepartureTime'].apply(lambda x: pd.to_datetime(x).month)
# train_data['season'] = train_data['month'].apply(func)
# train_data['weekend'] = train_data['DepartureTime'].apply(lambda x: 1 if pd.to_datetime(x).weekday() > 5 else 0)
# test_data['season'] = test_data['month'].apply(func)
# test_data['weekend'] = test_data['DepartureTime'].apply(lambda x: 1 if pd.to_datetime(x).weekday() > 5 else 0)

# %%
train_data['Male'] = train_data['Male'].replace({True: 1, False: 0})
test_data['Male'] = test_data['Male'].replace({True: 1, False: 0})
train_data['VehicleClass'] = train_data['VehicleClass'].replace({True: 1, False: 0})
test_data['VehicleClass'] = test_data['VehicleClass'].replace({True: 1, False: 0})
train_data['TripReason'] = train_data['TripReason'].replace({'Work': 1, 'Int': 0})

# %%
train_data['has discount'] = train_data['CouponDiscount'].apply(lambda x :(x > 1))
test_data['has discount'] = test_data['CouponDiscount'].apply(lambda x :(x > 1))
train_data['has discount'] = train_data['has discount'].replace({True: 1, False: 0})
test_data['has discount'] = test_data['has discount'].replace({True: 1, False: 0})

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler = MinMaxScaler()

train_data['CouponDiscount'] = Scaler.fit_transform(train_data[['CouponDiscount']])
train_data['Price'] = Scaler.fit_transform(train_data[['Price']])
test_data['CouponDiscount'] = Scaler.fit_transform(test_data[['CouponDiscount']])
test_data['Price'] = Scaler.fit_transform(test_data[['Price']])

# %%
from sklearn.preprocessing import LabelEncoder
Encoder = LabelEncoder()
Labels = ['From','To','VehicleType','Vehicle']
for i in Labels:
    train_data[i] = Encoder.fit_transform(train_data[i])
    test_data[i] = Encoder.fit_transform(test_data[i])

# %%
def func(month):
    if month == 0 or month == 3 or month == 4 or month == 5:
        return 1
    else:
        return 0
train_data['holiday'] = train_data['month'].apply(func)
test_data['holiday'] = test_data['month'].apply(func)
# def time_columns(df,columns):
#     for c in columns:
#         print(c)
#         df[c+'_month'] = df.loc[:,c].apply(lambda x: int(x[5:7]))
#         df[c+'_hour'] = df.loc[:,c].apply(lambda x: int(x[11:13]))

# time_columns(train_data, ['Created', 'DepartureTime'])
# time_columns(test_data, ['Created', 'DepartureTime'])

# %%
train_data.drop(columns = ['DepartureTime','Created','BillID','TicketID'],inplace = True)
test_data.drop(columns = ['CancelTime','UserID','HashPassportNumber_p','HashEmail','Created','BillID','TicketID','BuyerMobile','NationalCode','DepartureTime'],inplace = True)
train_data
# Out:
#         ReserveStatus  Male     Price  CouponDiscount  From   To  Domestic  \
# 0                   5     1  0.021060        0.002523   217   80         1
# 1                   5     1  0.028587        0.000139   171   80         1
# 2                   3     0  0.009121        0.000139   135   37         1
# 3                   2     0  0.004033        0.000139    64   85         1
# 4                   3     1  0.006863        0.000139    68  244         1
# ...               ...   ...       ...             ...   ...  ...       ...
# 101012              5     1  0.019243        0.000139   135  291         1
# 101013              2     1  0.006334        0.000139   179   80         1
# 101014              5     1  0.081795        0.000139   184   80         0
# 101015              3     1  0.006473        0.000139    27  306         1
# 101016              2     1  0.012152        0.000139   208   80         1
#
# ...

# %%
train_data.drop(columns = ['VehicleType'],inplace = True) 
test_data.drop(columns = ['VehicleType'],inplace = True) 
train_data
# Out:
#         ReserveStatus  Male     Price  CouponDiscount  From   To  Domestic  \
# 0                   5     1  0.021060        0.002523   217   80         1
# 1                   5     1  0.028587        0.000139   171   80         1
# 2                   3     0  0.009121        0.000139   135   37         1
# 3                   2     0  0.004033        0.000139    64   85         1
# 4                   3     1  0.006863        0.000139    68  244         1
# ...               ...   ...       ...             ...   ...  ...       ...
# 101012              5     1  0.019243        0.000139   135  291         1
# 101013              2     1  0.006334        0.000139   179   80         1
# 101014              5     1  0.081795        0.000139   184   80         0
# 101015              3     1  0.006473        0.000139    27  306         1
# 101016              2     1  0.012152        0.000139   208   80         1
#
# ...

# %%
# Data Selection
from sklearn.model_selection import train_test_split

x = train_data.drop(columns = ['TripReason']) 
y = train_data['TripReason']
x_train , x_test , y_train ,y_test  = train_test_split(x , y)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     حال که داده را پاکسازی کرده و احتمالا ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌اید، وقت آن است که مدلی آموزش دهید که بتواند متغیر هدف این مسئله را پیش‌بینی کند.
#     <br>
#     بر خلاف سایر تمرین‌های کالج، در این تمرین شما مجاز هستید از هر مدلی که آموخته‌اید استفاده کنید. به عبارت بهتر، هدف این سوال پیش‌بینی هرچه بهتر متغیر هدف مسئله است. انتظار ما این است که نحوه کار با کتابخانه‌های یادگیری ماشین را در حدی آموخته باشید که بتوانید با بهترین عملکرد، مسئله را حل کنید!
# </font>
# </p>

# %%
# Gird Search
# from sklearn.model_selection import GridSearchCV
# import xgboost as xgb
# param_grid = {
#     'max_depth': [3,5,7,10,15,20,25],
#     'learning_rate': [0.01,0.1,0.2,0.25,0.3],
#     'n_estimators': [100,150,200,300,400],
#     'min_child_weight' : [1,3,5,7],
#     'subsample': [0.8,1.0,1.2,1.5,2],
#     'gamma' : [0.1,0.2,0.4,0.6,0.8,1],
#     'colsample_bytree' : [0.3,0.4,0.5,0.7],
    
    
# } 
# clf = GridSearchCV(estimator = xgb.XGBClassifier() , param_grid = param_grid , scoring = 'f1' , verbose = 0)
# clf.fit(x,y)
# clf.best_estimator_

# %%
# modeling 
# from sklearn.linear_model import LinearRegression #18
# model = LinearRegression()
# from sklearn.ensemble import RandomForestClassifier #82
# model = RandomForestClassifier(n_estimators=100 , min_samples_split=2)
# from sklearn.linear_model import LogisticRegression #71
# model = LogisticRegression(max_iter=100)
# from sklearn.neighbors import KNeighborsClassifier #77
# model = KNeighborsClassifier(n_neighbors = 100 , p = 2 , weights = 'uniform')
# from sklearn.svm import SVC # no result
# model = SVC()
# from sklearn.ensemble import AdaBoostClassifier  #80
# from sklearn.tree import DecisionTreeClassifier
# model = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=4, min_samples_split=5, random_state=42), n_estimators=100, learning_rate=0.1, random_state=42)
# from sklearn.ensemble import GradientBoostingClassifier #79
# model = GradientBoostingClassifier(learning_rate=0.1, n_estimators=100)
import xgboost as xgb

model = xgb.XGBClassifier(max_depth = 7 ,learning_rate = 0.2 , n_estimators = 200 , subsample = 0.8 , min_child_weight = 1, gamma = 1 )
# model.fit(x_train,y_train)

# from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
# base_estimator = RandomForestClassifier(n_estimators=20, max_depth=10, random_state=42)

# model = AdaBoostClassifier(base_estimator=base_estimator, n_estimators=50, random_state=42)
# model.fit(x_train, y_train)

# from sklearn.ensemble import RandomForestClassifier

# model = RandomForestClassifier(n_estimators=300, max_depth=200,bootstrap=True,oob_score=True,max_samples=101017)
# model.fit(train_data_abstract_df,y_train_data)

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، <code>f1_score</code> نام دارد.
#     <br>
#     این معیار، سنجه ارزیابی کیفیت مدل شماست. به عبارت بهتر در سامانه داوری هم از همین معیار برای نمره‌دهی استفاده شده است.
#     <br>
#     پیشنهاد می‌شود با توجه به این معیار، عملکرد مدل خود را بر روی مجموعه داده آموزش یا اعتبارسنجی ارزیابی کنید.
# </font>
# </p>

# %%
# evaluate model
# from sklearn.metrics import  f1_score, classification_report, confusion_matrix
# y_pred = model.predict(x_test)
# print(f1_score(y_test,y_pred))

# %%
# training all data
model.fit(x,y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=1, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.2, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=7, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazirmatn" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>75%</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     پس از مهندسی ویژگی و مدلسازی، الگوریتمی دارید که می‌تواند شما را از متغیرهای مستقل به متغیر هدف برساند.
#     <br>
#     از این مدل برای پیش‌بینی نمونه‌های موجود در داده تست استفاده کنید و نتایج را در قالب جدول (<code>dataframe</code>) زیر آماده کنید.
# </font>
# </p>
#
# <div dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |ستون|توضیحات|
# |------|---|
# |TripReason|دلیل سفر|
#
# </font>
# </div>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     اسم دیتافریم باید <i>submission</i> باشد؛ در غیر این صورت، سامانه داوری نمی‌تواند تلاش‌ شما را ارزیابی کند.
#     <br>
#     این دیتافریم تنها شامل ۱ ستون با اسم <i>TripReason</i> است و ۴۳۲۹۳ سطر دارد.
#     <br>
#     به ازای هر سطر موجود در دیتافریم <i>test</i> شما باید یک مقدار پیشبینی شده داشته باشید.
#     <br>
#     جدول زیر، ۵ سطر ابتدایی دیتافریم <code>submission</code> را نشان می‌دهد. البته در جواب شما، مقادیر ستون <i>TripReason</i> ممکن است متفاوت باشد.
# </font>
# </p>
#
# <div style="text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# ||TripReason|
# |----|-----|
# |0|Work|
# |1|Work|
# |2|Int|
# |3|Int|
# |4|Work|
#
# </font>
# </div>

# %%
# predict test samples
submission = model.predict(test_data)
submission = pd.DataFrame(submission)
submission.columns = ['TripReason']
submission['TripReason'].replace({1 : 'Work' , 0 : 'Int'} , inplace = True)
submission
# Out:
#       TripReason
# 0           Work
# 1           Work
# 2           Work
# 3           Work
# 4           Work
# ...          ...
# 43288       Work
# 43289        Int
# 43290       Work
# 43291       Work
# 43292       Work
#
# [43293 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)
            
submission.to_csv('submission.csv', index=False)
file_names = ['tafrihi.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['tafrihi.ipynb', 'submission.csv']
